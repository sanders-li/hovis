# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json

# %%
df = pd.read_csv('reported_hospital_capacity_admissions_facility_level_weekly_average_timeseries_20210103_geocoded_metrics.csv', index_col=0)
df
# Out:
#                                               hospital_pk collection_week  \
# 0                                                  480001      2020-07-31
# 1                                                  171317      2020-07-31
# 2                                                  170013      2020-07-31
# 3                                                  171327      2020-07-31
# 4                                                  170023      2020-07-31
# ...                                                   ...             ...
# 106954                                             360179      2020-12-25
# 106955                                             362019      2020-12-25
# 106956                                             360001      2020-12-25
# 106957                                             360054      2020-12-25
# 106958  df2363988746840134806aa7b2accf9c89259601776986...      2020-12-25
#
#        state     ccn                              hospital_name  \
# ...

# %%
df_week = df.loc[df['collection_week'] == '2020-08-14'][['hospital_name', 'icu_occupancy']]
df_week
# Out:
#                                       hospital_name  icu_occupancy
# 9639                        DECATUR COUNTY HOSPITAL       0.000000
# 9640                   SOUTH CENTRAL KS  MED CENTER            NaN
# 9641   ASCENSION VIA CHRISTI HOSPITAL PITTSBURG INC       0.416667
# 9642                          GIRARD MEDICAL CENTER       0.500000
# 9643                              MEMORIAL HOSPITAL       0.000000
# ...                                             ...            ...
# 14416                          GRANT MEDICAL CENTER       0.844444
# 14417       SELECT SPECIALTY HOSPITAL-COLUMBUS, INC       0.000000
# 14418                  RIVERSIDE METHODIST HOSPITAL       0.981328
# 14420     MOUNT CARMEL NEW ALBANY SURGICAL HOSPITAL       0.000000
# 14421            SELECT SPECIALTY HOSPITAL COLUMBUS       0.650485
#
# [4698 rows x 2 columns]

# %%
df_week.sort_values(by='icu_occupancy', ascending=False)
# Out:
#                                hospital_name  icu_occupancy
# 11209  SOUTH BALDWIN REGIONAL MEDICAL CENTER       1.640000
# 14146             SCOTLAND MEMORIAL HOSPITAL       1.428571
# 10784            ANNE ARUNDEL MEDICAL CENTER       1.200000
# 12345    MUSC HEALTH FLORENCE MEDICAL CENTER       1.169565
# 10879       SALINAS VALLEY MEMORIAL HOSPITAL       1.167785
# ...                                      ...            ...
# 14086                  GRANDE RONDE HOSPITAL            NaN
# 14098                  UPMC BEDFORD MEMORIAL            NaN
# 14103                  CURAHEALTH PITTSBURGH            NaN
# 14119                              UPMC EAST            NaN
# 14192        HEART OF AMERICA MEDICAL CENTER            NaN
#
# [4698 rows x 2 columns]
